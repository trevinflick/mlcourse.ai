# %% [markdown]
# <center>
# <img src="../../img/ods_stickers.jpg" />
#
# ## [mlcourse.ai](mlcourse.ai) – Open Machine Learning Course
# Author: Arina Lopukhova (@erynn). Edited by [Yury Kashnitskiy](https://yorko.github.io) (@yorko). This material is subject to the terms and conditions of the [Creative Commons CC BY-NC-SA 4.0](https://creativecommons.org/licenses/by-nc-sa/4.0/) license. Free use is permitted for any non-commercial purpose.

# %% [markdown]
# <h1><center>Assignment #1. Fall 2018</center></h1>
# <h2><center>Exploratory data analysis of Olympic games with Pandas</center></h2>

# %% [markdown]
# __There are ten questions about [120 years of Olympic history: athletes and results](https://www.kaggle.com/heesoo37/120-years-of-olympic-history-athletes-and-results/version/2) dataset in this task. Your task is to fill in the missing Python code and choose answers in [this web-form](https://docs.google.com/forms/d/179HYvlF_0x435CWdu2aOtR9a3flh0YCQXXNXhXaKw2M).__

# %% [markdown]
# Download the file `athlete_events.csv` from [Kaggle page](https://www.kaggle.com/heesoo37/120-years-of-olympic-history-athletes-and-results). The dataset has the following features (copied from Kaggle):
#
# - __ID__ - Unique number for each athlete
# - __Name__ - Athlete's name
# - __Sex__ - M or F
# - __Age__ - Integer
# - __Height__ - In centimeters
# - __Weight__ - In kilograms
# - __Team__ - Team name
# - __NOC__ - National Olympic Committee 3-letter code
# - __Games__ - Year and season
# - __Year__ - Integer
# - __Season__ - Summer or Winter
# - __City__ - Host city
# - __Sport__ - Sport
# - __Event__ - Event
# - __Medal__ - Gold, Silver, Bronze, or NA

# %%
import pandas as pd

# %%
# Change the path to the dataset file if needed. 
PATH = '~/mlcourse.ai/data/athlete_events.csv'

# %%
data = pd.read_csv(PATH)
data.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %% [markdown]
# __1. How old were the youngest male and female participants of the 1996 Olympics?__
#
# - 16 and 15
# - 14 and 12
# - 16 and 12
# - 13 and 11

# %%
data[data.Year == 1996].groupby(['Sex']).min()
# Out:
#      ID                                     Name   Age  Height  Weight  \
# Sex
# F    13                          Aa Bela Joaquim  12.0   136.0    30.0
# M    30  A. J. Tyronne Benildus "Benny" Fernando  14.0   147.0    45.0
#
#             Team  NOC        Games  Year  Season     City    Sport  \
# Sex
# F        Albania  ALB  1996 Summer  1996  Summer  Atlanta  Archery
# M    Afghanistan  AFG  1996 Summer  1996  Summer  Atlanta  Archery
#
#                           Event
# Sex
# F    Archery Women's Individual
# M      Archery Men's Individual

# %% [markdown]
# __2. What was the percentage of male gymnasts among all the male participants of the 2000 Olympics? Round the answer to the first decimal.__
#
# *Hint:* here and further if needed drop duplicated sportsmen to count only unique ones.
#
# - 0.2
# - 1.5
# - 2.5
# - 7.7

# %%
# get data frame of gymnastics athletes for 2000 Olympics
gym = data[(data.Sport == "Gymnastics") & (data.Sex == "M")]

gym = gym[gym.Year == 2000]

# %%
# number of gymnastics athletes
len(gym["Name"].unique())
# Out:
# 97

# %%
# now count unique male athletes for 2000 Olympics
male = data[(data.Sex == "M") & (data.Year == 2000)]

len(male["Name"].unique())
# Out:
# 6576

# %%
(97 / 6576) * 100
# Out:
# 1.4750608272506083

# %% [markdown]
# __3. What are the mean and standard deviation of height for female basketball players participated in the 2000 Olympics? Round the answer to the first decimal.__
#
# - 178.5 and 7.2
# - 179.4 and 10
# - 180.7 and 6.7
# - 182.4 and 9.1

# %%
female_bb = data[(data.Year == 2000) & (data.Sex == "F") & (data.Sport == "Basketball")]

female_bb
# Out:
#             ID                                        Name Sex   Age  Height  \
# 1034       580                Svetlana Olegovna Abrosimova   F  20.0   188.0
# 1857      1020                Adriana Aparecida dos Santos   F  29.0   180.0
# 1863      1023            Adriana "Adrianinha" Moiss Pinto   F  21.0   170.0
# 4458      2546           Alessandra dos Santos de Oliveira   F  26.0   200.0
# 8185      4516                               Nicole Antibe   F  26.0   187.0
# 9273      5102                   Anna Valeryevna Arkhipova   F  27.0   176.0
# 9802      5366                  Olga Dmitriyevna Arteshina   F  17.0   191.0
# 22997    12087                        Cori Lyn Blakebrough   F  33.0   174.0
# 24918    13042        Alice Ruth "Ruthie" Bolton-Holifield   F  33.0   173.0
# 26741    13921                 Carolin Ruth "Cal" Bouchard   F  22.0   173.0
# 26796    13938                          Kelly Anne Boucher   F  32.0   187.0
# ...

# %%
female_bb['Height'].describe()
# Out:
# count    142.000000
# mean     182.387324
# std        9.139462
# min      162.000000
# 25%      175.000000
# 50%      182.000000
# 75%      190.000000
# max      213.000000
# Name: Height, dtype: float64

# %% [markdown]
# __4. Find a sportsperson participated in the 2002 Olympics, with the highest weight among other participants of the same Olympics. What sport did he or she do?__
#
# - Judo
# - Bobsleigh
# - Weightlifting
# - Boxing

# %%
olympics_2002 = data[data.Year == 2002]

olympics_2002.nlargest(5,'Weight')
# Out:
#             ID               Name Sex   Age  Height  Weight  \
# 99154    50171  Emmanuel Hostache   M  26.0   190.0   123.0
# 129595   65246        Kevin Kuske   M  23.0   196.0   116.0
# 270556  135315      Zsolt Zsombor   M  30.0   193.0   115.0
# 60488    30980        Dalibor uri   M  26.0   196.0   113.0
# 128125   64528       Pavel Kubina   M  24.0   196.0   113.0
#
#                          Team  NOC        Games  Year  Season            City  \
# 99154                  France  FRA  2002 Winter  2002  Winter  Salt Lake City
# 129595              Germany-2  GER  2002 Winter  2002  Winter  Salt Lake City
# 270556                Hungary  HUN  2002 Winter  2002  Winter  Salt Lake City
# 60488   Serbia and Montenegro  SCG  2002 Winter  2002  Winter  Salt Lake City
# 128125         Czech Republic  CZE  2002 Winter  2002  Winter  Salt Lake City
#
#              Sport                        Event Medal
# 99154    Bobsleigh          Bobsleigh Men's Two   NaN
# ...

# %% [markdown]
# __5. How many times did Pawe Abratkiewicz participate in the Olympics held in different years?__
#
# - 0
# - 1
# - 2
# - 3

# %%
Pawe = data[data.Name == "Pawe Abratkiewicz"]

Pawe["Year"].unique()
# Out:
# array([1992, 1998, 2002])

# %% [markdown]
# __6. How many silver medals in tennis did Australia win at the 2000 Olympics?__
#
# - 0
# - 1
# - 2
# - 3

# %%
Aus_2000 = data[(data.Year == 2000) & (data.NOC == "AUS")]
Aus_2000
# Out:
#             ID                                  Name Sex   Age  Height  \
# 470        257                              Ali Abdo   M  19.0   169.0
# 1467       817                  Gerard "Gerry" Adams   M  38.0   177.0
# 1468       817                  Gerard "Gerry" Adams   M  38.0   177.0
# 2348      1311           Nicholas Mark "Nick" A'Hern   M  31.0   169.0
# 2755      1534                          Brett Aitken   M  29.0   173.0
# 2756      1534                          Brett Aitken   M  29.0   173.0
# 3851      2221                  Dianne Marie Alagich   F  21.0   169.0
# 4996      2850               Kate Ruth "Katie" Allen   F  26.0   170.0
# 5050      2875     Sandra Louise "Sandy" Allen-Lewis   F  21.0   170.0
# 6779      3803                Craig Anthony Anderson   M  19.0   187.0
# 6901      3877      Kate Suzanne Anderson-Richardson   F  26.0   168.0
# 7438      4164         Susan Elizabeth "Sue" Andrews   F  29.0   173.0
# ...

# %%
Aus_2000[(Aus_2000.Sport == "Tennis") & (Aus_2000.Medal == "Silver")]
# Out:
#             ID                    Name Sex   Age  Height  Weight       Team  \
# 262820  131504  Todd Andrew Woodbridge   M  29.0   178.0    75.0  Australia
# 262831  131511  Mark Raymond Woodforde   M  34.0   183.0    80.0  Australia
#
#         NOC        Games  Year  Season    City   Sport                 Event  \
# 262820  AUS  2000 Summer  2000  Summer  Sydney  Tennis  Tennis Men's Doubles
# 262831  AUS  2000 Summer  2000  Summer  Sydney  Tennis  Tennis Men's Doubles
#
#          Medal
# 262820  Silver
# 262831  Silver

# %% [markdown]
# __7. Is it true that Switzerland won fewer medals than Serbia at the 2016 Olympics? Do not consider NaN values in _Medal_ column.__
#
# - Yes
# - No

# %%
swiss = data[(data.Year == 2016) & (data.Team == "Switzerland")]
serbia = data[(data.Year == 2016) & (data.Team == "Serbia")]

# %%
swiss_medals = swiss[swiss.Medal.notnull()]
serbia_medals = serbia[serbia.Medal.notnull()]

# %%
swiss_medals["Event"].unique()
# Out:
# array(["Tennis Women's Doubles", "Cycling Men's Individual Time Trial",
#        "Shooting Women's Sporting Pistol, 25 metres",
#        "Rowing Men's Lightweight Coxless Fours",
#        "Cycling Men's Mountainbike, Cross-Country",
#        "Triathlon Women's Olympic Distance",
#        "Gymnastics Women's Horse Vault"], dtype=object)

# %%
serbia_medals["Event"].unique()
# Out:
# array(["Water Polo Men's Water Polo", "Basketball Men's Basketball",
#        "Taekwondo Women's Flyweight", "Volleyball Women's Volleyball",
#        "Basketball Women's Basketball", "Athletics Women's Long Jump",
#        "Wrestling Men's Welterweight, Greco-Roman",
#        "Canoeing Men's Kayak Doubles, 1,000 metres"], dtype=object)

# %%
print(len(serbia_medals["Event"].unique()))
print(len(swiss_medals["Event"].unique()))
# Out:
# 8
# 7

# %% [markdown]
# __8. What age category did the fewest and the most participants of the 2014 Olympics belong to?__
# - [45-55] and [25-35) correspondingly
# - [45-55] and [15-25) correspondingly
# - [35-45] and [25-35) correspondingly
# - [45-55] and [35-45) correspondingly

# %%
olympics_2014 = data[data.Year == 2014]

# %%
def label_age(row):
    if (row['Age'] >= 15) & (row['Age'] < 25):
        return "[15-25)"
    elif (row['Age'] >= 25) & (row['Age'] < 35):
        return "[25-35)"
    elif (row['Age'] >= 35) & (row['Age'] < 45):
        return "[35-45)"
    elif (row['Age'] >= 45) & (row['Age'] <= 55):
        return "[45-55]"
    else:
        return "Other"

# %%
olympics_2014['age_group'] = olympics_2014.apply (lambda row: label_age(row),axis=1)
# Out:
# /Users/trevin/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
olympics_2014.groupby(["age_group"]).count()
# Out:
#              ID  Name   Sex   Age  Height  Weight  Team   NOC  Games  Year  \
# age_group
# [15-25)    2027  2027  2027  2027    2013    1897  2027  2027   2027  2027
# [25-35)    2594  2594  2594  2594    2588    2511  2594  2594   2594  2594
# [35-45)     265   265   265   265     265     261   265   265    265   265
# [45-55]       5     5     5     5       5       4     5     5      5     5
#
#            Season  City  Sport  Event  Medal
# age_group
# [15-25)      2027  2027   2027   2027    205
# [25-35)      2594  2594   2594   2594    352
# [35-45)       265   265    265    265     40
# [45-55]         5     5      5      5      0

# %% [markdown]
# __9. Is it true that there were Summer Olympics held in Lake Placid? Is it true that there were Winter Olympics held in Sankt Moritz?__
#
# - Yes, Yes
# - Yes, No
# - No, Yes
# - No, No

# %%
data["City"].unique()
# Out:
# array(['Barcelona', 'London', 'Antwerpen', 'Paris', 'Calgary',
#        'Albertville', 'Lillehammer', 'Los Angeles', 'Salt Lake City',
#        'Helsinki', 'Lake Placid', 'Sydney', 'Atlanta', 'Stockholm',
#        'Sochi', 'Nagano', 'Torino', 'Beijing', 'Rio de Janeiro', 'Athina',
#        'Squaw Valley', 'Innsbruck', 'Sarajevo', 'Mexico City', 'Munich',
#        'Seoul', 'Berlin', 'Oslo', "Cortina d'Ampezzo", 'Melbourne',
#        'Roma', 'Amsterdam', 'Montreal', 'Moskva', 'Tokyo', 'Vancouver',
#        'Grenoble', 'Sapporo', 'Chamonix', 'St. Louis', 'Sankt Moritz',
#        'Garmisch-Partenkirchen'], dtype=object)

# %%
# No
data[data.City == "Lake Placid"]
# Out:
#             ID                            Name Sex   Age  Height  Weight  \
# 30          11              Jorma Ilmari Aalto   M  22.0   182.0    76.5
# 675        393                     Gnther Abel   M  23.0   183.0    80.0
# 714        407               Ral Daniel Abella   M  26.0     NaN     NaN
# 715        407               Ral Daniel Abella   M  26.0     NaN     NaN
# 716        407               Ral Daniel Abella   M  26.0     NaN     NaN
# 923        523           Trond Sevg Abrahamsen   M  19.0   183.0    87.0
# 1326       746                     Goro Adachi   M  19.0   156.0    56.0
# 1691       938                Cary Glen Adgate   M  26.0   173.0    74.0
# 1799       998             ke Ronnie Adolfsson   M  23.0   180.0    77.0
# 1800       998             ke Ronnie Adolfsson   M  23.0   180.0    77.0
# 1801       998             ke Ronnie Adolfsson   M  23.0   180.0    77.0
# 2053      1138                    Iwao Ageishi   M  24.0   166.0    72.0
# ...

# %%
# Yes
data[data.City == "Sankt Moritz"]
# Out:
#             ID                                      Name Sex   Age  Height  \
# 935        529           Karl Gustaf Emanuel Abrahamsson   M  31.0     NaN
# 1187       665                     Gilbert Achard-Picard   M  29.0     NaN
# 1439       802                    Tadeusz Ralf Adamowski   M  26.0   177.0
# 1454       810         Bridget Shirley Adams (-Bengough)   F  19.0     NaN
# 2707      1508                            Enrico Airoldi   M  24.0     NaN
# 2708      1509                              Remo Airoldi   M  26.0     NaN
# 5053      2876                  Theodor "Theo" Allenbach   M  23.0     NaN
# 5054      2876                  Theodor "Theo" Allenbach   M  23.0     NaN
# 5132      2921                           Fernando Alloni   M  22.0     NaN
# 5332      3022                    Pentti Johannes Alonen   M  22.0   172.0
# 5333      3022                    Pentti Johannes Alonen   M  22.0   172.0
# ...

# %% [markdown]
# __10. What is the absolute difference between the number of unique sports at the 1995 Olympics and 2016 Olympics?__
#
# - 16
# - 24
# - 26
# - 34

# %%
oly_96 = data[data.Year == 1996]
oly_16 = data[data.Year == 2016]

# %%
len(oly_16["Event"].unique()) - len(oly_96["Event"].unique())
# Out:
# 35
